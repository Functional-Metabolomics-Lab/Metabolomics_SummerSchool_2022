# %% [markdown]
# # Cluster analysis and heatmaps
#
# Author: Francesco Russo, frru@ssi.dk<br>
# Last Update: August 17, 2022<br>
#
# Notebook for the International Summer School on non-targeted metabolomics 2022.<br>
#
# This notebook contains different cluster analyses to explore patterns in the data which help us to discover subgroups of samples or features that share a certain level of similarity. Clustering is an example of unsupervised learning where no labels are given to the learning algorithm which will try to find patterns/structures in the input data on its own. The goal of clustering is to find these hidden patterns.<br>
# Some types of cluster analyses (e.g. hierarchical clustering) are often associated with heatmaps. Heatmaps are a visual representation of the data where columns are usually samples and rows are features (in our case, different measurements of metabolic features). The color scale of heatmaps indicates higher or lower intensity (for instance, blue is lower and red is higher intensity).<br>
#
# There are a lot of good videos and resources out there explaining very well the principle behind clustering. Some good ones are the following:<br>
# - Hierarchical clustering and heatmaps: https://www.youtube.com/watch?v=7xHsRkOdVwo<br>
# - K-means clustering: https://www.youtube.com/watch?v=4b5d3muPQmA
# - ComplexHeatmap R package: https://jokergoo.github.io/ComplexHeatmap-reference/book/
#
# **Data**
#
# The files used in this tutorial are part of an interlab comparison study, where different laboratories around the world analysed same environmental samples on their respective LC-MS/MS equipments. To simulate algal bloom, standardized algae extracts (A) in marine dissolved organic matter (M) at different concentrations were prepared (450 (A45M), 150 (A15M), and 50 (A5M) ppm A). Samples were then shipped to different laboratories for untargeted LC-MS/MS metabolomics analysis. In this tutorial we are working with one of the datasets, which was acquired on a UHPLC system coupled to a Thermo Scientific Q Exactive HF Orbitrap LC-MS/MS mass spectrometer. MS/MS data were acquired in data-dependent acquisition (DDA) with fragmentation of the five most abundant ions in the spectrum per precursor scan. Data files were subsequently preprocessed using MZmine3 and the feature-based molecular networking workflow in GNPS.<br>
#
# **Questions**
#
# - Can we monitor algal bloom by looking at metabolomic profiles of marine dissolved organic matter?
# - Are we able to group/cluster together samples derived from different concentrations of algae extracts using metabolic profiles? <br>
# - Which samples are the most similar? <br>
# - Are there any patterns defining the groups/clusters? That is, which features cluster together?

# %%
# Last update
Sys.time()
# Out:
# [1] "2022-08-17 08:29:45 UTC"

# %% [markdown]
# **Install packages**

# %%
# It might take some time in Google Colab
install.packages("BiocManager")
BiocManager::install("ComplexHeatmap")
install.packages(c("dplyr","dendextend","NbClust","factoextra"))
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# '?repositories' for details
#
# replacement repositories:
#     CRAN: https://cran.rstudio.com
#
#
# Bioconductor version 3.15 (BiocManager 1.30.18), R 4.2.1 (2022-06-23)
#
# Installing package(s) 'BiocVersion', 'ComplexHeatmap'
#
# also installing the dependencies ‘shape’, ‘rjson’, ‘BiocGenerics’, ‘S4Vectors’, ‘iterators’, ‘circlize’, ‘GetoptLong’, ‘clue’, ‘GlobalOptions’, ‘png’, ‘IRanges’, ‘matrixStats’, ‘foreach’, ‘doParallel’
#
#
# Old packages: 'devtools', 'googlesheets4', 'pillar', 'rmarkdown', 'roxygen2',
#   'tibble', 'tidyverse', 'tinytex'
#
# Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘gridExtra’, ‘viridis’

# %% [markdown]
# **Load libraries**

# %%
library("dplyr")
library("ComplexHeatmap")
library("dendextend")
library("NbClust")
library("factoextra")
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: grid
#
# ========================================
# ComplexHeatmap version 2.12.1
# Bioconductor page: http://bioconductor.org/packages/ComplexHeatmap/
# Github page: https://github.com/jokergoo/ComplexHeatmap
# Documentation: http://jokergoo.github.io/ComplexHeatmap-reference
#
# If you use it in published research, please cite either one:
# - Gu, Z. Complex heatmaps reveal patterns and correlations in multidimensional
#     genomic data. Bioinformatics 2016.
# - Gu, Z. Complex Heatmap Visualization. iMeta 2022.
#
#
# The new InteractiveComplexHeatmap package can directly export static
# complex heatmaps into an interactive Shiny app with zero effort. Have a try!
#
# This message can be suppressed by:
#   suppressPackageStartupMessages(library(ComplexHeatmap))
# ========================================
#
#
#
# ---------------------
# Welcome to dendextend version 1.16.0
# Type citation('dendextend') for how to cite the package.
#
# Type browseVignettes(package = 'dendextend') for the package vignette.
# The github page is: https://github.com/talgalili/dendextend/
#
# Suggestions and bug-reports can be submitted at: https://github.com/talgalili/dendextend/issues
# You may ask questions at stackoverflow, use the r and dendextend tags:
# 	 https://stackoverflow.com/questions/tagged/dendextend
#
# 	To suppress this message use:  suppressPackageStartupMessages(library(dendextend))
# ---------------------
#
#
#
# Attaching package: ‘dendextend’
#
#
# The following object is masked from ‘package:stats’:
#
#     cutree

# %% [markdown]
# **Importing feature table and metadata**<br>
# In the following, we import the cleaned and imputed feature table (performed by Abzer, GitHub: @abzer005).<br>
# Here, we import the files from GitHub but you can import them from your local computer or from Google Drive as well of course. We import the cleaned and imputed but not normalized feature table.

# %%
# feature table
ft_url <- 'https://raw.githubusercontent.com/Functional-Metabolomics-Lab/Metabolomics_SummerSchool_2022/main/data/dom/processed/Imputed_QuantTable_filled_with_MinValue_8115_CutOff_Used_0.3.csv'
# metadata
md_url <- 'https://raw.githubusercontent.com/Functional-Metabolomics-Lab/Metabolomics_SummerSchool_2022/main/data/dom/metadata_lab15.txt'

# %%
# read data
ft <- read.csv(ft_url, header = T, check.names = F, row.names = 1)
md <- read.csv(md_url, header = T, check.names = F, sep = '\t', row.names = 1)

# %%
# dimension of the data
dim(ft)
dim(md)
# Out:
# [1] 4641   15
# [1] 16  3

# %%
head(ft)
# Out:
#                      DOM_Interlab-LCMS_Lab15_A_Pos_MS2_rep1.mzML
# 725_152.071_3.252      8115.00
# 1105_152.107_4.734    73926.81
# 21233_153.091_8.525    8115.00
# 2431_153.139_5.391   180359.25
# 29517_157.101_10.487   8115.00
# 1064_158.097_4.708     8115.00
#                      DOM_Interlab-LCMS_Lab15_A_Pos_MS2_rep2.mzML
# 725_152.071_3.252      8115.00
# 1105_152.107_4.734    75761.62
# 21233_153.091_8.525    8115.00
# 2431_153.139_5.391   211909.86
# 29517_157.101_10.487   8115.00
# 1064_158.097_4.708    13308.73
#                      DOM_Interlab-LCMS_Lab15_A_Pos_MS2_rep3.mzML
# 725_152.071_3.252      8115.00
# 1105_152.107_4.734    79481.29
# 21233_153.091_8.525    8115.00
# 2431_153.139_5.391   207134.48
# 29517_157.101_10.487   8115.00
# 1064_158.097_4.708    18052.25
#                      DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep1.mzML
# 725_152.071_3.252     75374.20
# 1105_152.107_4.734    27020.12
# 21233_153.091_8.525  225190.95
# 2431_153.139_5.391    29363.96
# 29517_157.101_10.487  71343.02
# 1064_158.097_4.708   129383.70
#                      DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep2.mzML
# 725_152.071_3.252     76915.33
# 1105_152.107_4.734    34365.83
# 21233_153.091_8.525  237659.23
# 2431_153.139_5.391    46186.89
# 29517_157.101_10.487  82697.29
# 1064_158.097_4.708   138584.53
#                      DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep3.mzML
# 725_152.071_3.252     77477.00
# 1105_152.107_4.734    30656.02
# 21233_153.091_8.525  236631.94
# 2431_153.139_5.391    40957.55
# 29517_157.101_10.487  67153.98
# 1064_158.097_4.708   172888.81
#                      DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep1.mzML
# 725_152.071_3.252     73175.08
# 1105_152.107_4.734    47937.98
# 21233_153.091_8.525  136346.10
# 2431_153.139_5.391   121025.35
# 29517_157.101_10.487 128506.03
# 1064_158.097_4.708   112905.93
#                      DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep2.mzML
# 725_152.071_3.252     72739.46
# 1105_152.107_4.734    48518.27
# 21233_153.091_8.525  143093.28
# 2431_153.139_5.391   131464.40
# 29517_157.101_10.487 143593.75
# 1064_158.097_4.708   128750.09
#                      DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep3.mzML
# 725_152.071_3.252     75286.51
# 1105_152.107_4.734    53590.48
# 21233_153.091_8.525  177747.20
# 2431_153.139_5.391   129922.91
# 29517_157.101_10.487 103605.84
# 1064_158.097_4.708   141072.06
#                      DOM_Interlab-LCMS_Lab15_A5M_Pos_MS2_rep1.mzML
# 725_152.071_3.252     59132.383
# 1105_152.107_4.734    14726.919
# 21233_153.091_8.525  191593.340
# 2431_153.139_5.391     8422.089
# 29517_157.101_10.487  65401.074
# 1064_158.097_4.708   127666.730
#                      DOM_Interlab-LCMS_Lab15_A5M_Pos_MS2_rep2.mzML
# 725_152.071_3.252     62091.973
# 1105_152.107_4.734    13063.939
# 21233_153.091_8.525  167290.800
# 2431_153.139_5.391     9051.153
# 29517_157.101_10.487  64061.840
# 1064_158.097_4.708   117818.770
#                      DOM_Interlab-LCMS_Lab15_A5M_Pos_MS2_rep3.mzML
# 725_152.071_3.252     63070.29
# 1105_152.107_4.734    20211.17
# 21233_153.091_8.525  225893.94
# 2431_153.139_5.391    10725.53
# 29517_157.101_10.487  58416.25
# 1064_158.097_4.708   150741.73
#                      DOM_Interlab-LCMS_Lab15_M_Pos_MS2_rep1.mzML
# 725_152.071_3.252     54793.090
# 1105_152.107_4.734     9119.948
# 21233_153.091_8.525  216016.230
# 2431_153.139_5.391     8115.000
# 29517_157.101_10.487  57274.220
# 1064_158.097_4.708   120658.320
#                      DOM_Interlab-LCMS_Lab15_M_Pos_MS2_rep2.mzML
# 725_152.071_3.252     65684.95
# 1105_152.107_4.734    12656.36
# 21233_153.091_8.525  224237.86
# 2431_153.139_5.391     8115.00
# 29517_157.101_10.487  63363.50
# 1064_158.097_4.708   145458.47
#                      DOM_Interlab-LCMS_Lab15_M_Pos_MS2_rep3.mzML
# 725_152.071_3.252     65077.08
# 1105_152.107_4.734    10552.45
# 21233_153.091_8.525  235601.08
# 2431_153.139_5.391     8115.00
# 29517_157.101_10.487  59016.21
# 1064_158.097_4.708    97648.51

# %%
head(md)
# Out:
#                                                ATTRIBUTE_Sample
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep1.mzML A15M
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep2.mzML A15M
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep3.mzML A15M
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep1.mzML A45M
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep2.mzML A45M
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep3.mzML A45M
#                                                ATTRIBUTE_Sample_Type
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep1.mzML Sample
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep2.mzML Sample
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep3.mzML Sample
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep1.mzML Sample
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep2.mzML Sample
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep3.mzML Sample
#                                                ATTRIBUTE_Time-Point
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep1.mzML 15
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep2.mzML 15
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep3.mzML 15
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep1.mzML 45
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep2.mzML 45
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep3.mzML 45

# %%
# show the type and number of samples we have
table(md$ATTRIBUTE_Sample)
# Out:
#    A A15M A45M  A5M    M  PPL
#    3    3    3    3    3    1

# %% [markdown]
# **Bring feature table and metadata in the correct format**
#
# As the purpose of the experiment is to test whether algal bloom could be monitored using metabolomics, we will remove all samples containing the pure algae extract (A).

# %%
ft <- ft[,-grep('_A_',colnames(ft))]

# %%
dim(ft)
# Out:
# [1] 4641   12

# %%
# some metabolic features are only present in A samples, we will thus remove all rows which have a mean minimum value equal to the minimum value in the feature table (as we imputed 0s)
ft <- ft[-which(rowMeans(ft) == min(ft)),]

# %%
dim(ft)
# Out:
# [1] 4338   12

# %%
# how many files in the metadata are also present in the feature table
table(rownames(md) %in% colnames(ft))
# Out:
# FALSE  TRUE
#     4    12

# %%
# which file names in the metadata are not in the feature table?
setdiff(rownames(md),colnames(ft))
# Out:
# [1] "DOM_Interlab-LCMS_Lab15_A_Pos_MS2_rep1.mzML"
# [2] "DOM_Interlab-LCMS_Lab15_A_Pos_MS2_rep2.mzML"
# [3] "DOM_Interlab-LCMS_Lab15_A_Pos_MS2_rep3.mzML"
# [4] "DOM_Interlab-LCMS_Lab15_PPL_Pos_MS2.mzML"

# %% [markdown]
# The blank sample 'DOM_Interlab-LCMS_Lab15_PPL_Pos_MS2.mzML' and all algae extract samples are not in the feature table, we thus remove it also from the metadata.

# %%
md <- md[rownames(md) %in% colnames(ft),]

# %%
dim(md)
# Out:
# [1] 12  3

# %%
# transpose ft
ft <- t(ft)

# %%
head(ft)
# Out:
#                                                725_152.071_3.252
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep1.mzML 75374.20
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep2.mzML 76915.33
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep3.mzML 77477.00
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep1.mzML 73175.08
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep2.mzML 72739.46
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep3.mzML 75286.51
#                                                1105_152.107_4.734
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep1.mzML 27020.12
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep2.mzML 34365.83
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep3.mzML 30656.02
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep1.mzML 47937.98
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep2.mzML 48518.27
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep3.mzML 53590.48
#                                                21233_153.091_8.525
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep1.mzML 225191.0
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep2.mzML 237659.2
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep3.mzML 236631.9
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep1.mzML 136346.1
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep2.mzML 143093.3
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep3.mzML 177747.2
#                                                2431_153.139_5.391
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep1.mzML  29363.96
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep2.mzML  46186.89
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep3.mzML  40957.55
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep1.mzML 121025.35
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep2.mzML 131464.40
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep3.mzML 129922.91
#                                                29517_157.101_10.487
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep1.mzML  71343.02
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep2.mzML  82697.29
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep3.mzML  67153.98
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep1.mzML 128506.03
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep2.mzML 143593.75
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep3.mzML 103605.84
#                                                1064_158.097_4.708
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep1.mzML 129383.7
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep2.mzML 138584.5
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep3.mzML 172888.8
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep1.mzML 112905.9
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep2.mzML 128750.1
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep3.mzML 141072.1
#                                                26713_158.154_9.707
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep1.mzML 164203.80
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep2.mzML 163637.66
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep3.mzML 176019.48
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep1.mzML  28441.68
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep2.mzML  32720.08
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep3.mzML  29002.01
#                                                30776_159.117_10.771
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep1.mzML 131556.3
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep2.mzML 103880.5
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep3.mzML 111611.9
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep1.mzML 267293.8
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep2.mzML 237352.9
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep3.mzML 140196.6
#                                                35547_159.117_12.158
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep1.mzML 86565.45
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep2.mzML 87226.39
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep3.mzML 60114.65
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep1.mzML 59101.73
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep2.mzML 67396.44
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep3.mzML 75238.78
#                                                542_160.076_1.42 ⋯
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep1.mzML 42241.05         ⋯
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep2.mzML 38578.97         ⋯
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep3.mzML 36412.93         ⋯
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep1.mzML 32380.98         ⋯
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep2.mzML 29624.18         ⋯
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep3.mzML 35465.69         ⋯
#                                                35117_1095.579_12.041
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep1.mzML  8115.00
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep2.mzML 10019.16
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep3.mzML  8115.00
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep1.mzML  8115.00
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep2.mzML  8115.00
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep3.mzML  8115.00
#                                                35071_1117.561_12.038
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep1.mzML  8115.00
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep2.mzML  8115.00
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep3.mzML 10167.15
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep1.mzML  8115.00
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep2.mzML  8115.00
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep3.mzML  8115.00
#                                                35024_1130.612_12.01
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep1.mzML  9513.445
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep2.mzML 12964.404
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep3.mzML  9329.693
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep1.mzML  8115.000
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep2.mzML  8115.000
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep3.mzML  8115.000
#                                                35371_1135.577_12.116
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep1.mzML 172358.34
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep2.mzML 126573.78
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep3.mzML 100383.16
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep1.mzML  21918.85
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep2.mzML  41131.29
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep3.mzML  79698.49
#                                                35029_1157.552_12.019
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep1.mzML 15317.47
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep2.mzML  8115.00
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep3.mzML 25070.96
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep1.mzML  8115.00
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep2.mzML  8115.00
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep3.mzML  8115.00
#                                                35365_1157.552_12.103
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep1.mzML 55698.43
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep2.mzML 51185.12
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep3.mzML 60067.83
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep1.mzML 19305.04
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep2.mzML 17351.03
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep3.mzML 37773.48
#                                                39600_1351.995_14.71
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep1.mzML  8115.000
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep2.mzML 10381.513
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep3.mzML 11082.286
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep1.mzML  9613.375
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep2.mzML 11499.083
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep3.mzML 12044.457
#                                                39696_1380.018_15.041
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep1.mzML  72585.75
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep2.mzML  91288.84
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep3.mzML  77523.42
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep1.mzML 172199.90
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep2.mzML 188047.39
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep3.mzML 171291.16
#                                                39693_1402.004_15.039
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep1.mzML 29325.84
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep2.mzML 42208.33
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep3.mzML 37471.21
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep1.mzML 58304.16
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep2.mzML 48458.56
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep3.mzML 42626.68
#                                                39001_1436.089_13.449
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep1.mzML 39565.41
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep2.mzML  8115.00
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep3.mzML  8115.00
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep1.mzML  8115.00
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep2.mzML  8115.00
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep3.mzML 27945.41

# %%
dim(ft)
# Out:
# [1]   12 4338

# %% [markdown]
# **Clustering analysis and heatmaps**
#
# In the following code, we will perform a clustering analysis and visualize a heatmap. We will 'decorate' our heatmap with some annotations derived from the metadata to show 'ATTRIBUTE_Sample' and 'ATTRIBUTE_Time-Point'. We will use the R package ComplexHeatmap (https://jokergoo.github.io/ComplexHeatmap-reference/book/introduction.html) which is a very flexible package for visualizing heatmaps (not just one! It is also possible to combine several heatmaps! It means you can plot for example one heatmap for the showing untargeted metabolomics, one with gene expression data, one for genetics etc etc).

# %%
identical(rownames(ft),rownames(md))
# put the rows in the feature table and metadata in the same order
ft <- ft[match(rownames(md),rownames(ft)),]
identical(rownames(ft),rownames(md))
# Out:
# [1] TRUE
# [1] TRUE

# %% [markdown]
# It is important that you scale your feature values in order to obtain a meaningful clustering. Each samples' feature values are represented as coordinates in n-dimensional space (n is the number of features) and then the distances between these coordinates are calculated. If these coordinates are not normalized you can get misleading/false results.<br>
#
# The following scale() function will ensure your distribution of feature values has mean 0 and a standard deviation of 1.

# %%
# center and scale data
fts <- scale(ft, center = T, scale = T)

# %%
head(fts)
# Out:
#                                                725_152.071_3.252
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep1.mzML 0.9069049
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep2.mzML 1.1073514
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep3.mzML 1.1804045
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep1.mzML 0.6208789
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep2.mzML 0.5642203
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep3.mzML 0.8955003
#                                                1105_152.107_4.734
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep1.mzML 0.009411123
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep2.mzML 0.464750893
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep3.mzML 0.234790491
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep1.mzML 1.306049295
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep2.mzML 1.342020176
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep3.mzML 1.656431717
#                                                21233_153.091_8.525
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep1.mzML  0.6414716
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep2.mzML  0.9782439
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep3.mzML  0.9504965
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep1.mzML -1.7582570
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep2.mzML -1.5760135
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep3.mzML -0.6399997
#                                                2431_153.139_5.391
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep1.mzML -0.325352876
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep2.mzML  0.004539484
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep3.mzML -0.098006353
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep1.mzML  1.472097585
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep2.mzML  1.676804008
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep3.mzML  1.646575962
#                                                29517_157.101_10.487
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep1.mzML -0.30933165
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep2.mzML  0.07977544
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep3.mzML -0.45288854
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep1.mzML  1.64962589
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep2.mzML  2.16667709
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep3.mzML  0.79630457
#                                                1064_158.097_4.708
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep1.mzML -0.1314608
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep2.mzML  0.3371554
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep3.mzML  2.0843386
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep1.mzML -0.9707052
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep2.mzML -0.1637318
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep3.mzML  0.4638502
#                                                26713_158.154_9.707
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep1.mzML  1.012924
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep2.mzML  1.002306
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep3.mzML  1.234527
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep1.mzML -1.533296
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep2.mzML -1.453055
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep3.mzML -1.522787
#                                                30776_159.117_10.771
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep1.mzML  0.002948166
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep2.mzML -0.461948839
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep3.mzML -0.332076607
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep1.mzML  2.283058890
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep2.mzML  1.780113691
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep3.mzML  0.148088154
#                                                35547_159.117_12.158
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep1.mzML  1.6612270
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep2.mzML  1.7098756
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep3.mzML -0.2856738
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep1.mzML -0.3602297
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep2.mzML  0.2502996
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep3.mzML  0.8275320
#                                                542_160.076_1.42 ⋯
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep1.mzML  0.5952840       ⋯
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep2.mzML -0.1139094       ⋯
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep3.mzML -0.5333818       ⋯
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep1.mzML -1.3142051       ⋯
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep2.mzML -1.8480828       ⋯
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep3.mzML -0.7168243       ⋯
#                                                35117_1095.579_12.041
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep1.mzML -0.2886751
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep2.mzML  3.1754265
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep3.mzML -0.2886751
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep1.mzML -0.2886751
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep2.mzML -0.2886751
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep3.mzML -0.2886751
#                                                35071_1117.561_12.038
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep1.mzML -0.2886751
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep2.mzML -0.2886751
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep3.mzML  3.1754265
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep1.mzML -0.2886751
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep2.mzML -0.2886751
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep3.mzML -0.2886751
#                                                35024_1130.612_12.01
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep1.mzML  0.5453231
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep2.mzML  2.9686670
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep3.mzML  0.4162882
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep1.mzML -0.4366976
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep2.mzML -0.4366976
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep3.mzML -0.4366976
#                                                35371_1135.577_12.116
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep1.mzML  2.1630996
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep2.mzML  1.3587669
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep3.mzML  0.8986561
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep1.mzML -0.4797872
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep2.mzML -0.1422675
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep3.mzML  0.5352724
#                                                35029_1157.552_12.019
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep1.mzML  1.0093619
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep2.mzML -0.3915869
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep3.mzML  2.9065074
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep1.mzML -0.3915869
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep2.mzML -0.3915869
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep3.mzML -0.3915869
#                                                35365_1157.552_12.103
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep1.mzML  1.5069406
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep2.mzML  1.2912033
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep3.mzML  1.7157984
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep1.mzML -0.2326690
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep2.mzML -0.3260708
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep3.mzML  0.6501250
#                                                39600_1351.995_14.71
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep1.mzML -0.7521355
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep2.mzML  0.7043016
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep3.mzML  1.1546109
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep1.mzML  0.2107043
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep2.mzML  1.4224402
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep3.mzML  1.7728918
#                                                39696_1380.018_15.041
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep1.mzML -0.006697906
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep2.mzML  0.264717619
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep3.mzML  0.064956580
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep1.mzML  1.438882841
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep2.mzML  1.668858466
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep3.mzML  1.425695387
#                                                39693_1402.004_15.039
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep1.mzML 0.1186648
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep2.mzML 0.8333953
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep3.mzML 0.5705764
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep1.mzML 1.7264050
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep2.mzML 1.1801632
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep3.mzML 0.8566057
#                                                39001_1436.089_13.449
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep1.mzML  0.23687343
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep2.mzML -0.60220220
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep3.mzML -0.60220220
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep1.mzML -0.60220220
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep2.mzML -0.60220220
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep3.mzML -0.07314028

# %% [markdown]
# **Hierarchical Clustering Algorithm**
#
# We are now ready to perform a cluter analysis. We start with hierarchical clustering. The concept behind hierarchical clustering is to repeatedly combine the two nearest clusters into a larger cluster. <br>
#
# 1. The first step consists of calculating the distance between every pair of observation points and stores it in a matrix;<br>
# 2. It puts every point in its own cluster;<br>
# 3. It merges the closest pairs of points according to their distances;<br>
# 4. It recomputes the distance between the new cluster and the old ones and stores them in a new distance matrix;<br>
# 5. It repeats steps 2 and 3 until all the clusters are merged into one single cluster.<br>
#
# In the following step we calculate the distance between data points based on Euclidean distance. You can choose another proper distance for continuous values here https://www.rdocumentation.org/packages/stats/versions/3.6.2/topics/dist. For example: 'manhattan', 'canberra', 'minkowski'.

# %%
# compute distance
distm <- dist(fts, method = "euclidean")

# %% [markdown]
# Next, we perform the hierarchical clustering. As you can see in the following code we need to specify the 'method' argument. This argument tells the algorithm how to measure the distance between clusters and it's usually referred as 'Linkage Method'. There are several and you can explore different options here https://www.rdocumentation.org/packages/stats/versions/3.6.2/topics/hclust. Usually, you will try different ones and plot the result.<br>
#
# Here, we use the default 'complete' (i.e. complete-linkage), which calculates the maximum distance between clusters before merging.

# %%
# we set a seed to get always the same result
set.seed(1234)
hclust_res <- hclust(distm, method = 'complete')

# %% [markdown]
# Then, we plot the result. In hierarchical clustering, we visualize the cluster relationships in a tree-like diagram called dendrogram. The distance of split or merge is called height.

# %%
plot(hclust_res)
# Out:
# Plot with title “Cluster Dendrogram”

# %% [markdown]
# Next, you can cut the dendrogram to create the desired number of clusters. In this case 3 main clusters seem to appear. We are going to use the cutree() function for this https://www.rdocumentation.org/packages/stats/versions/3.6.2/topics/cutree.

# %%
cut_res <- cutree(hclust_res, k = 3) # where k indicates the number of clusters we want

# %%
# the cluster assignment
data.frame(cut_res)
# Out:
#                                                cut_res
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep1.mzML 1
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep2.mzML 1
# DOM_Interlab-LCMS_Lab15_A15M_Pos_MS2_rep3.mzML 1
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep1.mzML 2
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep2.mzML 2
# DOM_Interlab-LCMS_Lab15_A45M_Pos_MS2_rep3.mzML 2
# DOM_Interlab-LCMS_Lab15_A5M_Pos_MS2_rep1.mzML  3
# DOM_Interlab-LCMS_Lab15_A5M_Pos_MS2_rep2.mzML  3
# DOM_Interlab-LCMS_Lab15_A5M_Pos_MS2_rep3.mzML  3
# DOM_Interlab-LCMS_Lab15_M_Pos_MS2_rep1.mzML    3
# DOM_Interlab-LCMS_Lab15_M_Pos_MS2_rep2.mzML    3
# DOM_Interlab-LCMS_Lab15_M_Pos_MS2_rep3.mzML    3

# %%
# you can also count how many samples are in each cluster
table(data.frame(cut_res))
# Out:
# cut_res
# 1 2 3
# 3 3 6

# %% [markdown]
# We can highlight the clusters in the dendrogram as well.

# %%
plot(hclust_res)
rect.hclust(hclust_res, k = 3, border = 1:3)
# Out:
# Plot with title “Cluster Dendrogram”

# %% [markdown]
# We can color the samples by cluster assignment using the dendextend package.

# %%
dend_obj <- as.dendrogram(hclust_res)
col_dend <- color_branches(dend_obj, k = 3)
plot(col_dend)
# Out:
# plot without title

# %% [markdown]
# Can we define the number of clusters using a simple approach? We are going to use the NbClust and factoextra packages for this purpose.<br>
#
# We start with the Elbow approach. The Elbow method looks at the total within-cluster sum of square (WSS) as a function of the number of clusters.
# WSS: sum of distances between the points and the corresponding centroids for each cluster.

# %%
# Elbow method. Here we use 'hcut' which computes the hierarchical clustering and cut the tree. Other methods are available (https://www.rdocumentation.org/packages/factoextra/versions/1.0.7/topics/fviz_nbclust)
fviz_nbclust(fts, hcut, method = "wss") +
  geom_vline(xintercept = 3, linetype = 2) + # add line indicating what you think is the optimal number of clusters
  labs(subtitle = "Elbow method") # add subtitle
# Out:
# plot without title

# %% [markdown]
# The location of a 'elbow' in the plot is usually considered as an indicator of the appropriate number of clusters because it means that adding another cluster does not improve the grouping. This method seems to suggest 3 clusters. However, the Elbow method is sometimes ambiguous. As we can see from the plot above, the 'elbow' could be located at 2 or 3 clusters. <br>
# An alternative is the average silhouette method. The Silhouette method measures the quality of a clustering and determines how well each point lies within its cluster.

# %%
# Silhouette method
fviz_nbclust(fts, hcut, method = "silhouette") +
  labs(subtitle = "Silhouette method")
# Out:
# plot without title

# %% [markdown]
# In this case, the silouette method seems to find two main clusters. There are several other methods to discover the optimal number of clusters and sometimes they do not fully agree. Often, you will need to bring your own knowledge about the specific field to decide whether the number of clusters makes sense.

# %% [markdown]
# As you can see, no matter which approach we use for finding the optimal number of clusters, the hierarchical clustering was able to identify meaningful clusters. However, based on the parameters that we have selected it seems that sample types 'M' and 'A5M' cluster together. Is this meaningful?<br>
#
# Sometimes, you may get unexpected results that are not only related to the selection of parameters but also to the input data. For instance, noisy data will lead to different clusters and interpretation of the results. For example, you could consider to remove features having zero-variance or zero Median Absolute Deviation prior to perform any further downstream analysis (remember that we usually impute quite a lot of data in metabolomics and this could create this zero-variance issue).

# %%
# If you want to remove features having zero Median Absolute Deviation, you can use the following function (just replace 'mad' with 'var' for the variance).
removeZeroMad <- function(df){
  df[, sapply(df, mad) != 0]
}

# %%
# we apply the function to the input data before scaling
ft_noZeroMad <- removeZeroMad(as.data.frame(ft))

# %% [markdown]
# As you can see, some features were removed after this filtering step.

# %%
dim(ft_noZeroMad)
# Out:
# [1]   12 3928

# %% [markdown]
# What happen if we perform clustering again?

# %%
# first, we scale the matrix
ft_noZeroMad_s <- scale(ft_noZeroMad, scale = T, center = T)
# then we calculate the distance matrix
distm_noZeroMad <- dist(ft_noZeroMad_s, method = "euclidean")
# then we perform clustering
set.seed(1234)
hclust_noZeroMad <- hclust(distm_noZeroMad, method = 'complete')
# finally, we plot the result
plot(hclust_noZeroMad)
# Out:
# Plot with title “Cluster Dendrogram”

# %% [markdown]
# In this case, the result is not affected and 'M' and 'A5M' samples still cluster together. This is also a nice proof that the noisy features that we have removed might not contribute much to the clustering and the interpretation of the result is still the same. Therefore, 'M' and 'A5M' samples share clear metabolic similarities.

# %% [markdown]
# **Heatmaps**
#
# In the next section we will add an additional layer in our visualization by plotting a heatmap together with the hierarchical clustering.<br>
#
# First, we prepare the 'decoration' for our heatmap. We want to show the 'ATTRIBUTE_Sample' and 'ATTRIBUTE_Time-Point' colored in a distinctive way. It is much easier to read the heatmap in this way.<br>
#
# We are going to use the ComplexHeatmap package https://jokergoo.github.io/ComplexHeatmap/reference/Heatmap.html

# %%
# metadata of interest
table(md$`ATTRIBUTE_Time-Point`)
table(md$ATTRIBUTE_Sample)
# Out:
#  0  5 15 45
#  3  3  3  3
# A15M A45M  A5M    M
#    3    3    3    3

# %%
# prepare a dataframe with just the metadata of interest
ann <- data.frame(md$ATTRIBUTE_Sample, md$`ATTRIBUTE_Time-Point`)
# assign better column names to the dataframe
colnames(ann) <- c('Sample', 'Time_point')
# select some colors of your choice. You can explore more colors by using the RColorBrewer package
colours <- list('Sample' = c('M' = 'grey', 'A5M' = 'darkorange', 'A15M' = 'darkred', 'A45M' = 'darkgreen'),
  'Time_point' = c('0' = 'grey', '5' = 'darkorange', '15' = 'darkred', '45' = 'darkgreen'))
# the function in ComplexHeatmap for preparing the annotation object 
colAnn <- HeatmapAnnotation(df = ann,
  col = colours,
  annotation_width = unit(c(1, 4), 'cm'),
  gap = unit(1, 'mm'))

# %% [markdown]
# ComplexHeatmap gives you a flexible function and it is easy to change parameters. You can take a look at the options here https://jokergoo.github.io/ComplexHeatmap/reference/Heatmap.html <br>
#
# In the following, we will perform hierarchical clustering based on Euclidean distance. ComplexHeatmap uses the R package hclust for this purpose, that we already saw in the previous section. As we said, Euclidean distance is just an example that fits well continuous numerical values in your dataset but there are several distance measures such as Manhattan, Minkowski, Canberra etc.<br>
# If you have binary data, you may consider to use Jaccard distance.

# %%
# set the parameters for the type of clustering to perform. You can play with different options
set.seed(1234)
hmap <- Heatmap(
  t(fts),
  heatmap_legend_param = list(title = "Scaled/centered\nintensity"), 
  col = c("blue","white","darkred"),
  show_row_names = FALSE,
  show_column_names = FALSE,
  cluster_rows = TRUE,
  cluster_columns = TRUE,
  show_column_dend = TRUE,
  show_row_dend = TRUE,
  row_dend_reorder = TRUE,
  column_dend_reorder = TRUE,
  clustering_distance_rows = "euclidean",
  clustering_distance_columns = "euclidean",
  clustering_method_rows = "complete",
  clustering_method_columns = "complete",
  width = unit(100, "mm"),
  top_annotation = colAnn)
# Out:
# `use_raster` is automatically set to TRUE for a matrix with more than
# 2000 rows. You can control `use_raster` argument by explicitly setting
# TRUE/FALSE to it.
#
# Set `ht_opt$message = FALSE` to turn off this message.
#
# 'magick' package is suggested to install to give better rasterization.
#
# Set `ht_opt$message = FALSE` to turn off this message.

# %%
# draw heatmap. It can take some time if your input data is quite large
draw(hmap, heatmap_legend_side="right", annotation_legend_side="right")
# Out:
# plot without title

# %% [markdown]
# As we can see, by using this type of visualization we can clearly observe the similarities between samples and features, in particular we can again see that sample types 'M' and 'A5M' are quite similar. We can also apply a method for dividing the heatmap according to a cluster assignment, similarly to the cutree() step, for generating better visualizations that can help the interpretation of the results.<br>
#
# ComplexHeatmap contains a function to find clusters by using another clustering algorithm called **k-means**.

# %%
# set the parameters for the type of clustering to perform. You can play with different options
set.seed(1234)
hmap_km <- Heatmap(
  t(fts),
  heatmap_legend_param = list(title = "Scaled/centered\nintensity"), 
  col = c("blue","white","darkred"),
  show_row_names = FALSE,
  show_column_names = FALSE,
  cluster_rows = TRUE,
  cluster_columns = TRUE,
  show_column_dend = TRUE,
  show_row_dend = TRUE,
  row_dend_reorder = TRUE,
  column_dend_reorder = TRUE,
  clustering_distance_rows = "euclidean",
  clustering_distance_columns = "euclidean",
  clustering_method_rows = "complete",
  clustering_method_columns = "complete",
  width = unit(100, "mm"),
  top_annotation = colAnn,
  # parameters to perform k-means clustering. row_km indicates the number of clusters you want in the rows; column_km is referred to the number of clusters you want in the columns
  row_km = 3, row_km_repeats = 100,
  column_km = 3, column_km_repeats = 100)
# Out:
# `use_raster` is automatically set to TRUE for a matrix with more than
# 2000 rows. You can control `use_raster` argument by explicitly setting
# TRUE/FALSE to it.
#
# Set `ht_opt$message = FALSE` to turn off this message.
#
# 'magick' package is suggested to install to give better rasterization.
#
# Set `ht_opt$message = FALSE` to turn off this message.

# %%
# draw heatmap. It can take some time if your input data is quite large
draw(hmap_km, heatmap_legend_side="right", annotation_legend_side="right")
# Out:
# plot without title

# %% [markdown]
# In the next step, we extract the features belonging to the clusters for future use.

# %%
row_order_res <- row_order(draw(hmap_km, heatmap_legend_side="right", annotation_legend_side="right"))
# Out:
# plot without title

# %%
# check/confirm size of clusters
lapply(row_order_res, function(x) length(x))
# Out:
# $`1`
# [1] 2248
#
# $`2`
# [1] 1053
#
# $`3`
# [1] 1037

# %%
# loop to extract features for each cluster
out_res <- NULL
for (i in seq_along(row_order_res)){
out_res[[i]] <- cbind(colnames(fts[,row_order_res[[i]]]), paste("cluster", i, sep=""))  
}

# %%
out_res <- as.data.frame(do.call(rbind, out_res))

# %%
colnames(out_res) <- c('feature','cluster')

# %%
# dimension of the object
dim(out_res)
# number of features in each cluster
table(out_res$cluster)
head(out_res)
# Out:
# [1] 4338    2
# cluster1 cluster2 cluster3
#     2248     1053     1037
#   feature              cluster
# 1 1349_380.229_4.944   cluster1
# 2 36627_298.367_12.531 cluster1
# 3 35556_539.289_12.14  cluster1
# 4 4918_293.149_5.991   cluster1
# 5 649_206.118_2.115    cluster1
# 6 30705_288.275_10.758 cluster1

# %%
# you can export the data frame for future use
# write.table(out_res, file = "feature_clusters.txt", sep="\t", quote = F, row.names = FALSE)

# %% [markdown]
# **Summary**
#
# In this notebook you have performed hierarchical clustering, found optimal number of clusters, plotted heatmaps and performed K-means clustering to obtain well defined clusters. In the last step, we have extracted a data frame with feature and cluster assignment. You can use this output for further analyses. For example, you could add the annotation of the features obtained elsewhere using GNPS or Sirius and check if the clustering makes sense at a class level. You might want to play with different settings by changing the parameters for the clustering.<br>
#
# **Note**: usually, finding the correct number of clusters is not a trivial task and it is also an open scientific question. However, several methods are available to help us in the decision. There are several R packages to help us in this task:<br>
# https://cran.r-project.org/web/packages/NbClust/index.html <br>
# https://cran.r-project.org/web/packages/fpc/index.html <br>
#
# These packages can also be used for determining the stability of the clusters (that is, are the clusters assigned by random chance?).

# %%
# for reproducibility
sessionInfo()
# Out:
# R version 4.2.1 (2022-06-23)
# Platform: x86_64-pc-linux-gnu (64-bit)
# Running under: Ubuntu 18.04.6 LTS
#
# Matrix products: default
# BLAS:   /usr/lib/x86_64-linux-gnu/openblas/libblas.so.3
# LAPACK: /usr/lib/x86_64-linux-gnu/libopenblasp-r0.2.20.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] grid      stats     graphics  grDevices utils     datasets  methods
# [8] base
#
# other attached packages:
# [1] dendextend_1.16.0     ComplexHeatmap_2.12.1 RColorBrewer_1.1-3
# [4] dplyr_1.0.9
#
# loaded via a namespace (and not attached):
#  [1] pbdZMQ_0.3-7        circlize_0.4.15     shape_1.4.6
#  [4] GetoptLong_1.0.5    tidyselect_1.1.2    repr_1.1.4
#  [7] purrr_0.3.4         colorspace_2.0-3    vctrs_0.4.1
# [10] generics_0.1.3      viridisLite_0.4.0   htmltools_0.5.3
# [13] stats4_4.2.1        base64enc_0.1-3     utf8_1.2.2
# [16] rlang_1.0.4         pillar_1.7.0        glue_1.6.2
# [19] DBI_1.1.3           BiocGenerics_0.42.0 uuid_1.1-0
# [22] matrixStats_0.62.0  foreach_1.5.2       lifecycle_1.0.1
# [25] munsell_0.5.0       gtable_0.3.0        GlobalOptions_0.1.2
# [28] codetools_0.2-18    evaluate_0.15       IRanges_2.30.0
# [31] fastmap_1.1.0       doParallel_1.0.17   parallel_4.2.1
# [34] fansi_1.0.3         IRdisplay_1.1       scales_1.2.0
# [37] BiocManager_1.30.18 IRkernel_1.3        S4Vectors_0.34.0
# [40] jsonlite_1.8.0      gridExtra_2.3       rjson_0.2.21
# [43] ggplot2_3.3.6       png_0.1-7           digest_0.6.29
# [46] clue_0.3-61         cli_3.3.0           tools_4.2.1
# [49] magrittr_2.0.3      tibble_3.1.7        cluster_2.1.3
# [52] crayon_1.5.1        pkgconfig_2.0.3     ellipsis_0.3.2
# [55] viridis_0.6.2       assertthat_0.2.1    iterators_1.0.14
# [58] R6_2.5.1            compiler_4.2.1
